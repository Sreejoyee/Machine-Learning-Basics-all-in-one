# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, mean_squared_error

# %% [markdown]
# # LINEAR REGRESSION
#
# The dataset used is [California Housing Prices](https://www.kaggle.com/datasets/camnugent/california-housing-prices)

# %%
# data preparation
data = pd.read_csv("/kaggle/input/random-linear-regression/train.csv")
test = pd.read_csv("/kaggle/input/random-linear-regression/test.csv")
test
# Out:
#       x          y
# 0    77  79.775152
# 1    21  23.177279
# 2    22  25.609262
# 3    20  17.857388
# 4    36  41.849864
# ..   ..        ...
# 295  71  68.545888
# 296  46  47.334876
# 297  55  54.090637
# 298  62  63.297171
# 299  47  52.459467
#
# [300 rows x 2 columns]

# %%
# creating and running the model
from sklearn.linear_model import LinearRegression

X = np.array([[1, 1], [1, 2], [2, 2], [2, 3]])
y = np.dot(X, np.array([1, 2])) + 3
reg = LinearRegression().fit(X, y)
pred = reg.predict(X)
print(pred)
plt.scatter(range(len(pred)), pred)
plt.plot([min(range(len(pred))) , max(range(len(pred)))] , [min(pred) , max(pred)] , label='Original', color="red") #original data plot
# Out:
# [ 6.  8.  9. 11.]

# %% [markdown]
# # DECISION TREES
#
# The dataset used for demonstrating Decision Tree Classifier is [Banknote authentication](https://www.kaggle.com/datasets/shantanuss/banknote-authentication-uci)

# %%
# reading and preparing the data
dt_data = pd.read_csv("/kaggle/input/banknote-authentication-uci/BankNoteAuthentication.csv")
dt_data = dt_data.dropna()
y = dt_data["class"]
x = dt_data.drop(["class"], axis=1)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.33, random_state=42)

# %%
# creating and running the model
from sklearn import tree

dtc = tree.DecisionTreeClassifier()
dtc = dtc.fit(x_train, y_train)
y_pred = dtc.predict(x_test)
print(f"The accuracy of Decision Trees is: {accuracy_score(y_pred, y_test)}")
plt.scatter(y_pred, range(len(y_pred)))
plt.show()
# Out:
# The accuracy of Decision Trees is: 0.9823399558498896

# %% [markdown]
# # RANDOM FOREST
#
# We will be using the same `Bank Note Authentication` dataset for the demonstration of this algorithm

# %%
rf_data = pd.read_csv("/kaggle/input/banknote-authentication-uci/BankNoteAuthentication.csv")
rf_data = rf_data.dropna()
y = rf_data["class"]
x = rf_data.drop(["class"], axis=1)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.33, random_state=1)

# %%
from sklearn.ensemble import RandomForestClassifier

rfc = RandomForestClassifier(max_depth=2, random_state=1)
rfc = rfc.fit(x_train, y_train)
y_pred = rfc.predict(x_test)
print(f"The accuracy of Random forest classifier is: {accuracy_score(y_pred, y_test)}")
plt.scatter(y_pred, range(len(y_pred)))
plt.show()
# Out:
# The accuracy of Random forest classifier is: 0.9161147902869757

# %% [markdown]
# # ADABOOST CLASSIFIER
#
# The dataset used is `Bank Note Authentication`

# %%
abc_data = pd.read_csv("/kaggle/input/banknote-authentication-uci/BankNoteAuthentication.csv")
abc_data = abc_data.dropna()
y = abc_data["class"]
x = abc_data.drop(["class"], axis=1)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.33, random_state=0)

# %%
from sklearn.ensemble import AdaBoostClassifier

abc = AdaBoostClassifier(n_estimators=100, random_state=0)
abc = rfc.fit(x_train, y_train)
y_pred = abc.predict(x_test)
print(f"The accuracy of Ada Boost Classifier is: {accuracy_score(y_pred, y_test)}")
# Out:
# The accuracy of Ada Boost Classifier is: 0.9227373068432672

# %% [markdown]
# # GRADIENT BOOSTING CLASSIFIER
#
# The dataset used is `Bank Note Authentication`

# %%
gbc_data = pd.read_csv("/kaggle/input/banknote-authentication-uci/BankNoteAuthentication.csv")
gbc_data = gbc_data.dropna()
y = gbc_data["class"]
x = gbc_data.drop(["class"], axis=1)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.33, random_state=0)

# %%
from sklearn.ensemble import GradientBoostingClassifier

gbc = GradientBoostingClassifier(n_estimators=100, learning_rate=1.0, max_depth=2, random_state=0)
gbc = gbc.fit(x_train, y_train)
y_pred = gbc.predict(x_test)
print(f"The accuracy of Gradient Boost Classifier is: {accuracy_score(y_pred, y_test)}")
# Out:
# The accuracy of Gradient Boost Classifier is: 1.0

# %% [markdown]
# # LOGISTIC REGRESSION
#
# The dataset used is `Bank Note Authentication`

# %%
lgr_data = pd.read_csv("/kaggle/input/banknote-authentication-uci/BankNoteAuthentication.csv")
lgr_data = lgr_data.dropna()
y = lgr_data["class"]
x = lgr_data.drop(["class"], axis=1)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.33, random_state=0)

# %%
from sklearn.linear_model import LogisticRegression

lgr = LogisticRegression(random_state=0).fit(x_train, y_train)
y_pred = lgr.predict(x_test)
print(f"The accuracy of Logistic Regression is: {accuracy_score(y_pred, y_test)}")
# Out:
# The accuracy of Logistic Regression is: 0.9867549668874173

# %% [markdown]
# # SUPPORT VECTOR MACHINES
#
# The dataset used is `Bank Note Authentication`

# %%
svm_data = pd.read_csv("/kaggle/input/banknote-authentication-uci/BankNoteAuthentication.csv")
svm_data = svm_data.dropna()
y = svm_data["class"]
x = svm_data.drop(["class"], axis=1)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.33, random_state=0)
type(y_test)
# Out:
# pandas.core.series.Series

# %%
from sklearn.svm import SVC

svc = SVC(kernel="poly").fit(x_train, y_train)
y_pred = svc.predict(x_test)
print(f"The accuracy of SVM classifier is: {accuracy_score(y_pred, y_test)}")
# Out:
# The accuracy of SVM classifier is: 0.9690949227373068

# %% [markdown]
# # K NEAREST NEIGHBOURS
#
# The dataset used is `Bank Note Authentication`

# %%
knn_data = pd.read_csv("/kaggle/input/banknote-authentication-uci/BankNoteAuthentication.csv")
knn_data = knn_data.dropna()
y = knn_data["class"]
x = knn_data.drop(["class"], axis=1)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.33, random_state=0)

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=2)
knn = knn.fit(x_train, y_train)
y_pred = knn.predict(x_test)
print(f"The accuracy of KNN classifier is: {accuracy_score(y_pred, y_test)}")
# Out:
# The accuracy of KNN classifier is: 0.9977924944812362

# %% [markdown]
# # K-MEANS CLASSIFICATION
#
# The dataset is `Bank Note Authentication`

# %%
km_data = pd.read_csv("/kaggle/input/banknote-authentication-uci/BankNoteAuthentication.csv")
km_data = km_data.dropna()
y = km_data["class"]
x = km_data.drop(["class"], axis=1)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.33, random_state=0)

# %%
from sklearn.cluster import KMeans

km = KMeans(n_clusters=2, random_state=1).fit(x_train)
y_pred = km.predict(x_test)
print(f"The accuracy of K-Means is: {accuracy_score(y_pred, y_test)}")
# Out:
# The accuracy of K-Means is: 0.6357615894039735

# %% [markdown]
# # SVM 3d plot

# %%
from sklearn.svm import SVC
import numpy as np
import matplotlib.pyplot as plt
from sklearn import svm, datasets
from mpl_toolkits.mplot3d import Axes3D

iris = datasets.load_iris()
X = iris.data[:, :3]  # we only take the first three features.
Y = iris.target

#make it binary classification problem
X = X[np.logical_or(Y==0,Y==1)]
Y = Y[np.logical_or(Y==0,Y==1)]

model = svm.SVC(kernel='linear')
clf = model.fit(X, Y)

# The equation of the separating plane is given by all x so that np.dot(svc.coef_[0], x) + b = 0.
# Solve for w3 (z)
z = lambda x,y: (-clf.intercept_[0]-clf.coef_[0][0]*x -clf.coef_[0][1]*y) / clf.coef_[0][2]

tmp = np.linspace(-5,5,30)
x,y = np.meshgrid(tmp,tmp)

fig = plt.figure()
ax  = fig.add_subplot(111, projection='3d')
ax.plot3D(X[Y==0,0], X[Y==0,1], X[Y==0,2],'ob')
ax.plot3D(X[Y==1,0], X[Y==1,1], X[Y==1,2],'sr')
ax.plot_surface(x, y, z(x,y))
ax.view_init(30, 60)
plt.show()
